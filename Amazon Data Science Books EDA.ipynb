# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Custom Colors class
class clr:
    S = '\033[1m' + '\033[96m'  # Start color (bold + cyan)
    E = '\033[0m'               # End color (reset)
    my_colors = ["#C411ED", "#8D11F7", "#501BE0", "#1113F7", "#114CED"]

# Print message with custom color formatting
print(clr.S + "Notebook Color Scheme: " + clr.E)

# Display the custom color palette
sns.palplot(sns.color_palette(clr.my_colors))
plt.show()
# Out:
# Notebook Color Scheme:

# %%
#Environment check
import os
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Let's get the Data 📥

# %%
df = pd.read_csv('final_book_dataset_kaggle.csv')

# %%
df.head()
# Out:
#                                                title  \
# 0  Becoming a Data Head: How to Think Speak and U...
# 1  Ace the Data Science Interview: 201 Real Inter...
# 2  Fundamentals of Data Engineering: Plan and Bui...
# 3  Essential Math for Data Science: Take Control ...
# 4  Data Science for Business: What You Need to Kn...
#
#                               author  price  pages  avg_reviews  n_reviews  \
# 0  [Alex J. Gutman,Jordan Goldmeier]  24.49  272.0          4.6        184
# 1             [Nick Singh,Kevin Huo]  26.00  301.0          4.5        599
# 2            [Joe Reis,Matt Housley]  50.76  446.0          5.0         33
# 3                     [Thomas Nield]  44.80  347.0          4.5         27
# 4       [Foster Provost,Tom Fawcett]  36.99  413.0          4.5        970
#
#    star5  star4  star3  star2  star1             dimensions       weight  \
# 0   0.74   0.18   0.05   0.02   0.01    6 x 0.62 x 9 inches  12.5 ounces
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 946 entries, 0 to 945
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          946 non-null    object
#  1   author         824 non-null    object
#  2   price          944 non-null    float64
#  3   pages          934 non-null    float64
#  4   avg_reviews    823 non-null    float64
#  5   n_reviews      946 non-null    int64
#  6   star5          946 non-null    float64
#  7   star4          946 non-null    float64
#  8   star3          946 non-null    float64
#  9   star2          946 non-null    float64
#  10  star1          946 non-null    float64
#  11  dimensions     914 non-null    object
#  12  weight         943 non-null    object
#  13  language       943 non-null    object
#  14  publisher      942 non-null    object
#  15  ISBN_13        945 non-null    object
#  16  link           946 non-null    object
# ...

# %%
df.describe()
# Out:
#             price        pages  avg_reviews    n_reviews       star5  \
# count  944.000000   934.000000   823.000000   946.000000  946.000000
# mean    52.103528   419.356531     4.442163   137.754757    0.625603
# std     36.590725   203.984911     0.401256   499.485754    0.279219
# min      4.730000    48.000000     1.000000     0.000000    0.000000
# 25%     31.907500   272.000000     4.300000     5.000000    0.570000
# 50%     43.985000   384.000000     4.500000    25.000000    0.700000
# 75%     56.765000   531.500000     4.700000    91.000000    0.780000
# max    279.950000  1728.000000     5.000000  7563.000000    1.000000
#
#             star4       star3       star2       star1
# count  946.000000  946.000000  946.000000  946.000000
# mean     0.140835    0.058192    0.026575    0.018732
# std      0.113105    0.061997    0.038293    0.032132
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.070000    0.000000    0.000000    0.000000
# ...

# %%
df.isnull().any()
# Out:
# title            False
# author            True
# price             True
# pages             True
# avg_reviews       True
# n_reviews        False
# star5            False
# star4            False
# star3            False
# star2            False
# star1            False
# dimensions        True
# weight            True
# language          True
# publisher         True
# ISBN_13           True
# link             False
# complete_link    False
# dtype: bool

# %%
# Find null values and drop them

df.replace('Nan', np.nan, inplace = True)

# %%
df.dropna(axis = 0, inplace = True)

# %%
df.columns
# Out:
# Index(['title', 'author', 'price', 'pages', 'avg_reviews', 'n_reviews',
#        'star5', 'star4', 'star3', 'star2', 'star1', 'dimensions', 'weight',
#        'language', 'publisher', 'ISBN_13', 'link', 'complete_link'],
#       dtype='object')

# %% [markdown]
# # Let's explore the dataset 👓
# Which book (title) recieved max reviews?
#
# Which book has most percentage of 5 stars?
#
# Which publisher is most famous?
#
# Which language is most preffered by readers?
#
# What are the average number of pages in a data science book and the costliest book?
#
# Plot average reviews
#
# # Q1 Which book (title) recieved max reviews?

# %%
max_reviews = df['n_reviews'].max() 
review_book = df.loc[df['n_reviews'] == max_reviews, 'title'].iloc[0]
print(review_book, 'is the most reviewed book with max ', max_reviews, 'reviews')
# Out:
# Cracking the Coding Interview: 189 Programming Questions and Solutions is the most reviewed book with max  7563 reviews

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='n_reviews',y='title', data = df.head(10))
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.yticks(fontsize= 15)
plt.ylabel('Book Title')
plt.xlabel('Number of Reviews')
plt.title('Number of reviews per book')
# Out:
# Text(0.5, 1.0, 'Number of reviews per book')

# %% [markdown]
# # Q2 Which book has most percentage of 5 stars?

# %%
five_star = df['star5'].max()
five_star_book = df.loc[df['star5'] == five_star, 'title'].iloc[0]

print(five_star_book, ' got most percentage of 5 stars (', five_star, ')')
# Out:
# Effective Data Science Infrastructure: How to make data scientists productive  got most percentage of 5 stars ( 1.0 )

# %%
# Let's find out the number of reviews goto by the book to support our theory
n_reviews_five_star_book = df.loc[df['title'] == five_star_book, 'n_reviews'].iloc[0]
print(five_star_book, 'got ',n_reviews_five_star_book, ' reviews out of which 5 stars were ', five_star )
# Out:
# Effective Data Science Infrastructure: How to make data scientists productive got  5  reviews out of which 5 stars were  1.0

# %% [markdown]
# Since, 5 reviews are too small to say that most percent of 5 stars were actually a worth or not. Let's check percent of 5 stars on boo with most reviews.

# %%
maximum_reviews = df['n_reviews'].max()
five_star_on_max_n_reviews_book = df.loc[df['title'] == review_book, 'star5'].iloc[0]
print(review_book, 'got', five_star_on_max_n_reviews_book, 'percent of 5 stars and ', maximum_reviews, 'reviews')
# Out:
# Cracking the Coding Interview: 189 Programming Questions and Solutions got 0.81 percent of 5 stars and  7563 reviews

# %% [markdown]
# Thus, we found that the book with max reviews do have around 81% of 5 stars which is pretty good for a book.
#
# plt.figure(figsize=(40,40)) sns.barplot(x='star5',y='title', data = df.head(10)) sns.set(rc={'figure.figsize':(11.7,8.27)}) plt.yticks(fontsize= 32) plt.ylabel('Book Title') plt.xlabel('Rating') plt.title('Books with 5 star rating')

# %%
plt.figure(figsize=(40,40))
sns.barplot(x='star5',y='title', data = df.head(20))
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.yticks(fontsize= 36)
plt.ylabel('Book Title')
plt.xlabel('Rating')
plt.title('Books with 5 star rating')
# Out:
# Text(0.5, 1.0, 'Books with 5 star rating')

# %% [markdown]
# # Q3 Which publisher and author is most famous?

# %%
# Publishers vs n_reviews (max and min)
most_reviewed = df['n_reviews'].max()
star_publisher = df.loc[df['n_reviews'] == most_reviewed, 'publisher'].iloc[0]

print(star_publisher, ' got maximum number of reviews (', most_reviewed, ')')
# Out:
# CareerCup; 6th edition (July 1 2015)  got maximum number of reviews ( 7563 )

# %%
least_reviewed = df['n_reviews'].min()
_publisher = df.loc[df['n_reviews'] == most_reviewed, 'publisher'].iloc[0]

print(_publisher, ' got minimum number of reviews (', least_reviewed, ')')
# Out:
# CareerCup; 6th edition (July 1 2015)  got minimum number of reviews ( 1 )

# %%
# Define color palette
my_colors = ["#C411ED", "#8D11F7", "#501BE0", "#1113F7", "#114CED"]

# Use sns.catplot which creates its own figure
g = sns.catplot(
    x='n_reviews',
    y='publisher',
    data=df.head(50),
    kind='swarm',
    color=my_colors[2],
    height=12,
    aspect=2.5
)

# Customize plot
g.set_axis_labels("Number of Reviews", "Publisher", fontsize=12)
g.ax.set_title("Publishers and Number of Reviews per Their Books", fontsize=16)
g.ax.tick_params(axis='y', labelsize=8)

plt.tight_layout()
plt.show()

# %%
# Authors vs n_reviews (max and min)
most_reviewed = df['n_reviews'].max()
star_author = df.loc[df['n_reviews'] == most_reviewed, 'author'].iloc[0]

print(star_author, ' got maximum number of reviews (', most_reviewed, ')')
# Out:
# [Gayle Laakmann McDowell]  got maximum number of reviews ( 7563 )

# %%
least_reviewed = df['n_reviews'].min()
_author = df.loc[df['n_reviews'] == least_reviewed, 'author'].iloc[0]

print(_author, ' got least number of reviews (', least_reviewed, ')')
# Out:
# [Jordan Morrow]  got least number of reviews ( 1 )

# %%
plt.figure(figsize=(100, 100))
sns.catplot(x = 'n_reviews', y = 'author',data = df.head(20), kind = 'bar', color = my_colors[3])
plt.yticks(fontsize= 12)
plt.ylabel('author')
plt.xlabel('number of reviews')
plt.title('Authors and number of reviews per their books')
# Out:
# Text(0.5, 1.0, 'Authors and number of reviews per their books')

# %% [markdown]
# # Q4 Which language is most preffered by readers?

# %%
df['language'].unique()
# Out:
# array(['English', 'Spanish'], dtype=object)

# %%
preffered_language = df['language'].value_counts()
preffered_language
# Out:
# language
# English    697
# Spanish      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,8))
plt.bar(preffered_language.index, preffered_language, color = my_colors[1])
plt.show()

# %% [markdown]
# # Q5 What are the average number of pages in a data science book and the costliest book?

# %%
average_no_pages = df['pages'].mean()
print('Average pages per book are - ',average_no_pages)
# Out:
# Average pages per book are -  430.2378223495702

# %%
plt.figure(figsize=(20, 20))
sns.catplot(x = 'pages', y = 'title',data = df.head(20), kind = 'bar', color = my_colors[0])
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.yticks(fontsize= 6)
plt.ylabel('title')
plt.xlabel('pages')
plt.title('Title and number of pages')
# Out:
# Text(0.5, 1.0, 'Title and number of pages')

# %% [markdown]
# # Q6 Least and most priced Book

# %%
costliest = df['price'].max()
costliest_book = df.loc[df['price'] == costliest, 'title'].iloc[0]

print(costliest_book, 'is the costliest book priced at $', costliest)
# Out:
# Using SPSS for Windows and Macintosh (7th Edition) is the costliest book priced at $ 279.95

# %%
least_cost = df['price'].min()
least_costliest_book = df.loc[df['price'] == least_cost, 'title'].iloc[0]

print(least_costliest_book, 'is the costliest book priced at $', least_cost)
# Out:
# How to Work With Probability and Statistics Grades 6-8 (Math How To...) is the costliest book priced at $ 8.99

# %%
plt.figure(figsize=(15,8))
sns.catplot(x = 'price', y = 'title',data = df.head(10), kind = 'swarm', color = my_colors[1])
plt.yticks(fontsize= 6)
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.ylabel('title')
plt.xlabel('price in $')
plt.title('Title and its price')
# Out:
# Text(0.5, 1.0, 'Title and its price')

# %% [markdown]
# # Q7 Plot average reviews

# %%
df.columns
# Out:
# Index(['title', 'author', 'price', 'pages', 'avg_reviews', 'n_reviews',
#        'star5', 'star4', 'star3', 'star2', 'star1', 'dimensions', 'weight',
#        'language', 'publisher', 'ISBN_13', 'link', 'complete_link'],
#       dtype='object')

# %%
plt.figure(figsize=(15,8))
df['avg_reviews'].plot(color = my_colors[2])
plt.xlabel('count')
plt.ylabel('reviews')
plt.show()

# %% [markdown]
# From the above plot it is evident that average reviews lie in range 3.5 to 5.
